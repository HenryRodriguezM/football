-- %%
DESCRIBE EXTENDED catalog_football.bronze.clubs

-- %% [markdown]
-- ### Eliminación tablas de capa Bronze

-- %%
DROP TABLE IF EXISTS catalog_football.bronze.clubs;
DROP TABLE IF EXISTS catalog_football.bronze.players;
DROP TABLE IF EXISTS catalog_football.bronze.games;

-- %% [markdown]
-- ### Eliminación tablas de capa Silver

-- %%
DROP TABLE IF EXISTS catalog_football.silver.football_transformed

-- %% [markdown]
-- ### Eliminación tablas de capa Golden

-- %%
DROP TABLE IF EXISTS catalog_football.golden.ds_club_performance

-- %% [markdown]
-- ### Eliminación permisos en catalogo y esquemas

-- %%
REVOKE ALL PRIVILEGES ON CATALOG catalog_football FROM `Data_Engineers`;
REVOKE CREATE, USE SCHEMA ON SCHEMA catalog_football.bronze FROM `Data_Engineers`;
REVOKE CREATE, USE SCHEMA ON SCHEMA catalog_football.silver FROM `Data_Engineers`;
REVOKE CREATE, USE SCHEMA ON SCHEMA catalog_football.golden FROM `Data_Engineers`;

-- %% [markdown]
-- ### Eliminación permisos en External Locations

-- %%
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-raw` FROM `Data_Engineers`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-bronze` FROM `Data_Engineers`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-silver` FROM `Data_Engineers`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-golden` FROM `Data_Engineers`;
