-- %%
CREATE GROUP `Data_Engineers`;

-- %%
ALTER GROUP `Data_Engineers`
ADD USER `rodriguez.montero.henry@outlook.com`;

-- %%
ALTER GROUP `Data_Engineers`
ADD USER `henryrm33@gmail.com`;

-- %% [markdown]
-- ### Otorgar permisos al catalogo y los esquemas

-- %%
GRANT ALL PRIVILEGES ON CATALOG catalog_football TO `Data_Engineers`;
GRANT CREATE, USE SCHEMA ON SCHEMA catalog_football.bronze TO `Data_Engineers`;
GRANT CREATE, USE SCHEMA ON SCHEMA catalog_football.silver TO `Data_Engineers`;
GRANT CREATE, USE SCHEMA ON SCHEMA catalog_football.gold TO `Data_Engineers`;

-- %% [markdown]
-- ### Otorgar permisos a External Locations

-- %%
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-raw` TO `Data_Engineers`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-bronze` TO `Data_Engineers`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-silver` TO `Data_Engineers`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-golden` TO `Data_Engineers`;
